# %% [markdown]
# <a href="https://colab.research.google.com/github/Sashimimeow/-SC_Data_Visualization/blob/main/Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os

# %%
from google.colab import drive # เชื่อมบัญชีกับ google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#เข้าไป path ใน google drive
import os
os.chdir('/content/drive/Shareddrives')

# !pwd #เช็ค path ที่กำลังทำงานอยู่
# Out:
# /content/drive/Shareddrives

# %%
import pandas as pd
import os
os.chdir('/content/drive/MyDrive/Data-Viz-2023-2')

# %%
# !ls
# Out:
# ectreport2023.xlsx			 POS_transactions_20171207-20171219.csv
# ectreport66.xlsx			 POS_transactions_20190213-20190226.csv
# Final.pdf				 POS_transactions_20190328-20190410.csv
# POS_operator_logs_20171207-20171219.csv  table_merge_result.csv
# POS_operator_logs_20190213-20190226.csv  thai.json
# POS_operator_logs_20190328-20190410.csv

# %%
operator1 = pd.read_csv('/content/drive/MyDrive/Data-Viz-2023-2/POS_operator_logs_20171207-20171219.csv')
operator2 = pd.read_csv('/content/drive/MyDrive/Data-Viz-2023-2/POS_operator_logs_20190213-20190226.csv')
operator3  = pd.read_csv('/content/drive/MyDrive/Data-Viz-2023-2/POS_operator_logs_20190328-20190410.csv')
tran1 = pd.read_csv('/content/drive/MyDrive/Data-Viz-2023-2/POS_transactions_20171207-20171219.csv')
tran2 = pd.read_csv('/content/drive/MyDrive/Data-Viz-2023-2/POS_transactions_20190213-20190226.csv')
tran3= pd.read_csv('/content/drive/MyDrive/Data-Viz-2023-2/POS_transactions_20190328-20190410.csv')

# %%
operator1 = operator1 .head()
operator2 = operator1 .head()
operator3 = operator1 .head()

# %%
operator1 .info()
operator2 .info()
operator3 .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   WorkstationGroupID  5 non-null      int64
#  1   WorkstationID       5 non-null      int64
#  2   TranID              5 non-null      int64
#  3   BeginDateTime       5 non-null      object
#  4   OperatorID          5 non-null      int64
#  5   Items               5 non-null      object
# dtypes: int64(4), object(2)
# memory usage: 368.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   WorkstationGroupID  5 non-null      int64
#  1   WorkstationID       5 non-null      int64
#  2   TranID              5 non-null      int64
#  3   BeginDateTime       5 non-null      object
# ...

# %%
operator1 .describe()
# Out:
#        WorkstationGroupID  WorkstationID        TranID  OperatorID
# count                 5.0       5.000000  5.000000e+00    5.000000
# mean                  8.0      16.000000  1.712071e+12  266.000000
# std                   0.0       1.581139  1.581139e+01    1.581139
# min                   8.0      14.000000  1.712071e+12  264.000000
# 25%                   8.0      15.000000  1.712071e+12  265.000000
# 50%                   8.0      16.000000  1.712071e+12  266.000000
# 75%                   8.0      17.000000  1.712071e+12  267.000000
# max                   8.0      18.000000  1.712071e+12  268.000000

# %%
operator2 .describe()
# Out:
#        WorkstationGroupID  WorkstationID        TranID  OperatorID
# count                 5.0       5.000000  5.000000e+00    5.000000
# mean                  8.0      16.000000  1.712071e+12  266.000000
# std                   0.0       1.581139  1.581139e+01    1.581139
# min                   8.0      14.000000  1.712071e+12  264.000000
# 25%                   8.0      15.000000  1.712071e+12  265.000000
# 50%                   8.0      16.000000  1.712071e+12  266.000000
# 75%                   8.0      17.000000  1.712071e+12  267.000000
# max                   8.0      18.000000  1.712071e+12  268.000000

# %%
operator2 .describe()
# Out:
#        WorkstationGroupID  WorkstationID        TranID  OperatorID
# count                 5.0       5.000000  5.000000e+00    5.000000
# mean                  8.0      16.000000  1.712071e+12  266.000000
# std                   0.0       1.581139  1.581139e+01    1.581139
# min                   8.0      14.000000  1.712071e+12  264.000000
# 25%                   8.0      15.000000  1.712071e+12  265.000000
# 50%                   8.0      16.000000  1.712071e+12  266.000000
# 75%                   8.0      17.000000  1.712071e+12  267.000000
# max                   8.0      18.000000  1.712071e+12  268.000000

# %%
tran1.info()
tran2.info()
tran3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66863 entries, 0 to 66862
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   WorkstationGroupID  66863 non-null  int64
#  1   TranID              66863 non-null  int64
#  2   BeginDateTime       66863 non-null  object
#  3   EndDateTime         66863 non-null  object
#  4   OperatorID          66863 non-null  int64
#  5   TranTime            66863 non-null  int64
#  6   BreakTime           66863 non-null  int64
#  7   ArtNum              66863 non-null  int64
#  8   TNcash              66863 non-null  bool
#  9   TNcard              66863 non-null  bool
#  10  Amount              66863 non-null  float64
# dtypes: bool(2), float64(1), int64(6), object(2)
# memory usage: 4.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47066 entries, 0 to 47065
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ...

# %% [markdown]
# #Check NULL

# %%
operator1.isnull().any()
# Out:
# WorkstationGroupID    False
# WorkstationID         False
# TranID                False
# BeginDateTime         False
# OperatorID            False
# Items                 False
# dtype: bool

# %%
operator2.isnull().any()
# Out:
# WorkstationGroupID    False
# WorkstationID         False
# TranID                False
# BeginDateTime         False
# OperatorID            False
# Items                 False
# dtype: bool

# %%
operator3.isnull().any()
# Out:
# WorkstationGroupID    False
# WorkstationID         False
# TranID                False
# BeginDateTime         False
# OperatorID            False
# Items                 False
# dtype: bool

# %%
tran1.isnull().any()
# Out:
# WorkstationGroupID    False
# TranID                False
# BeginDateTime         False
# EndDateTime           False
# OperatorID            False
# TranTime              False
# BreakTime             False
# ArtNum                False
# TNcash                False
# TNcard                False
# Amount                False
# dtype: bool

# %%
tran2.isnull().any()
# Out:
# WorkstationGroupID    False
# TranID                False
# BeginDateTime         False
# EndDateTime           False
# OperatorID            False
# TranTime              False
# BreakTime             False
# ArtNum                False
# TNcash                False
# TNcard                False
# Amount                False
# dtype: bool

# %%
tran3.isnull().any()
# Out:
# WorkstationGroupID    False
# TranID                False
# BeginDateTime         False
# EndDateTime           False
# OperatorID            False
# TranTime              False
# BreakTime             False
# ArtNum                False
# TNcash                False
# TNcard                False
# Amount                False
# dtype: bool

# %%
operator = pd.concat([operator1,operator2,operator3],ignore_index=True)

# %%
transactions = pd.concat([tran1,tran2,tran3],ignore_index = True)

# %%
operator
# Out:
#     WorkstationGroupID  WorkstationID         TranID        BeginDateTime  \
# 0                    8             16  1712071060162  2017-12-07T06:04:01
# 1                    8             15  1712071060152  2017-12-07T06:04:15
# 2                    8             14  1712071060142  2017-12-07T06:05:36
# 3                    8             18  1712071060182  2017-12-07T06:05:41
# 4                    8             17  1712071060172  2017-12-07T06:05:56
# 5                    8             16  1712071060162  2017-12-07T06:04:01
# 6                    8             15  1712071060152  2017-12-07T06:04:15
# 7                    8             14  1712071060142  2017-12-07T06:05:36
# 8                    8             18  1712071060182  2017-12-07T06:05:41
# 9                    8             17  1712071060172  2017-12-07T06:05:56
# 10                   8             16  1712071060162  2017-12-07T06:04:01
# 11                   8             15  1712071060152  2017-12-07T06:04:15
# ...

# %%
aaa = transactions.merge(operator,how='left' , left_on='OperatorID' , right_on = 'OperatorID')
aaa
# Out:
#     WorkstationGroupID_x      TranID_x      BeginDateTime_x  \
# 0                      1  1.712071e+14  2017-12-07T14:23:23
# 1                      1  1.712071e+14  2017-12-07T14:25:09
# 2                      1  1.712071e+14  2017-12-07T14:27:28
# 3                      1  1.712071e+14  2017-12-07T14:28:04
# 4                      1  1.712071e+14  2017-12-07T14:29:40
# 5                      1  1.902231e+13  2019-02-23T14:35:12
# 6                      1  1.902131e+11  2019-02-13T07:50:14
# 7                      1  1.902131e+11  2019-02-13T07:50:40
# 8                      1  1.902131e+11  2019-02-13T07:54:30
# 9                      1  1.902131e+11  2019-02-13T07:55:21
# 10                     1  1.904031e+13  2019-04-03T13:28:17
# 11                     1  1.903291e+13  2019-03-29T14:04:50
# 12                     1  1.903291e+13  2019-03-29T14:05:52
# 13                     1  1.903291e+13  2019-03-29T14:07:19
# 14                     1  1.903291e+13  2019-03-29T14:08:08
#
# ...

# %%
transactions
# Out:
#     WorkstationGroupID        TranID        BeginDateTime  \
# 0                    1  1.712071e+14  2017-12-07T14:23:23
# 1                    1  1.712071e+14  2017-12-07T14:25:09
# 2                    1  1.712071e+14  2017-12-07T14:27:28
# 3                    1  1.712071e+14  2017-12-07T14:28:04
# 4                    1  1.712071e+14  2017-12-07T14:29:40
# 5                    1  1.902231e+13  2019-02-23T14:35:12
# 6                    1  1.902131e+11  2019-02-13T07:50:14
# 7                    1  1.902131e+11  2019-02-13T07:50:40
# 8                    1  1.902131e+11  2019-02-13T07:54:30
# 9                    1  1.902131e+11  2019-02-13T07:55:21
# 10                   1  1.904031e+13  2019-04-03T13:28:17
# 11                   1  1.903291e+13  2019-03-29T14:04:50
# 12                   1  1.903291e+13  2019-03-29T14:05:52
# 13                   1  1.903291e+13  2019-03-29T14:07:19
# 14                   1  1.903291e+13  2019-03-29T14:08:08
#
# ...

# %%
operator
# Out:
#     WorkstationGroupID  WorkstationID         TranID        BeginDateTime  \
# 0                    8             16  1712071060162  2017-12-07T06:04:01
# 1                    8             15  1712071060152  2017-12-07T06:04:15
# 2                    8             14  1712071060142  2017-12-07T06:05:36
# 3                    8             18  1712071060182  2017-12-07T06:05:41
# 4                    8             17  1712071060172  2017-12-07T06:05:56
# 5                    8             16  1712071060162  2017-12-07T06:04:01
# 6                    8             15  1712071060152  2017-12-07T06:04:15
# 7                    8             14  1712071060142  2017-12-07T06:05:36
# 8                    8             18  1712071060182  2017-12-07T06:05:41
# 9                    8             17  1712071060172  2017-12-07T06:05:56
# 10                   8             16  1712071060162  2017-12-07T06:04:01
# 11                   8             15  1712071060152  2017-12-07T06:04:15
# ...

# %%
data = pd.merge(transactions,operator=on'data')
# Out:
#   File "<ipython-input-46-3aa76434d3fd>", line 1
#     data = pd.merge(transactions,operator=on'data')
#                                             ^
# SyntaxError: invalid syntax
