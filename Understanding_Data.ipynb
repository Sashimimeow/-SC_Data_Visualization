# %% [markdown]
# <a href="https://colab.research.google.com/github/Sashimimeow/-SC_Data_Visualization/blob/main/Understanding_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Load Data

# %% [markdown]
# ##Load excel from google drive

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_from_gdrive = pd.read_excel('/content/drive/MyDrive/bsc_dpdm_23/2563.xls',header=2)
data_from_gdrive
# Out:
#     เลขที่คำขอ เลขที่บัตรส่งเสริม                        ชื่อบริษัทภาษาไทย  \
# 0       610707   62-0422-1-04-1-0  กรุงเทพ ไดอ์แคสซ์ติ้ง แอนด์ อินแจ๊กชั่น
# 1       620660   63-0107-1-00-1-0                        เจ้าพระยา คาร์บอน
# 2       610182   63-0101-1-00-1-0                        อาร์ต ออฟ เบคกิ้ง
# 3       620318   63-0080-1-00-0-0       เอ็นจีเค สปาร์คปลั๊กส์ (ประเทศไทย)
# 4       620185   63-0079-1-00-0-0       เอ็นจีเค สปาร์คปลั๊กส์ (ประเทศไทย)
# ..         ...                ...                                      ...
# 655    E630369   63-0669-1-00-0-0  อีเลคโทรลักซ์ โปรเฟสชั่นแนล (ประเทศไทย)
# 656    E630401   63-0682-1-00-1-0                            โกลว์ พลังงาน
# 657    E630277   63-0666-1-03-1-0         ยูนิค อุตสาหกรรมพลาสติก (แม่สอด)
# 658     610552   63-0676-1-00-1-0                   ไอชิน เอไอ (ประเทศไทย)
# 659    E630269   63-0668-1-00-1-0     เอ็มเอ็มซี อีเล็คโทรนิคส์ (ไทยแลนด์)
#
# ...

# %% [markdown]
# ##Load excel from google sheets

# %%
# !pip install gspread

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds,_ = default()

gc = gspread.authorize(creds)

# %%
gsht = gc.open_by_key('d/1M2gRXb-eSMS99RxQe6n2hQHhFPEzUgtJxQKp6gw9q1I/edit#gid=540437041')

# %%
worksheet2 = gsht.worksheet('มิ.ย. 2563')
rows = worksheet2.get_all_values()
data_from_gsheet = pd.DataFrame.from_records(rows)
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# <ipython-input-20-917378b0d78a> in <cell line: 1>()
# ----> 1 worksheet2 = gsht.worksheet('มิ.ย. 2563')
#       2 rows = worksheet2.get_all_values()
#       3 data_from_gsheet = pd.DataFrame.from_records(rows)
#
# /usr/local/lib/python3.10/dist-packages/gspread/models.py in worksheet(self, title)
#     312
#     313         """
# --> 314         sheet_data = self.fetch_sheet_metadata()
#     315         try:
#     316             item = finditem(
#
# /usr/local/lib/python3.10/dist-packages/gspread/models.py in fetch_sheet_metadata(self, params)
#     261         url = SPREADSHEET_URL % self.id
#     262
# --> 263         r = self.client.request('get', url, params=params)
#     264
#     265         return r.json()
#
# ...

# %% [markdown]
# ##New data

# %%
import pandas as pd

# %%
shopping_data = pd.read_csv('/content/drive/MyDrive/bsc_dpdm_23/shopping.csv')

# %% [markdown]
# #Basic stat

# %%
data_from_gdrive.describe()
# Out:
#         อุตสาหการ       ไฟฟ้า  อิเล็กทรอนิกส์และโทรคมนาคม   เครื่องกล  \
# count  660.000000  660.000000                  660.000000  660.000000
# mean     0.766667    0.933333                    0.568182    0.966667
# std      2.666053    2.102483                    3.711511    3.491865
# min      0.000000    0.000000                    0.000000    0.000000
# 25%      0.000000    0.000000                    0.000000    0.000000
# 50%      0.000000    0.000000                    0.000000    0.000000
# 75%      0.000000    1.000000                    0.000000    1.000000
# max     30.000000   23.000000                   69.000000   71.000000
#
#         วิศวะเคมี   ปิโตรเคมี        โยธา  คอมพิวเตอร์       สำรวจ  \
# count  660.000000  660.000000  660.000000   660.000000  660.000000
# mean     0.128788    0.010606    0.022727     0.827273    0.007576
# std      0.590842    0.116380    0.235857     3.343353    0.116617
# ...

# %%
shopping_data
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
shopping_data.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %% [markdown]
# ##Quiz

# %% [markdown]
# ####How many payment methods?

# %%
payment_method_counts = shopping_data['Payment Method'].value_counts()
print("Payment Method Counts:")
print(payment_method_counts)
# Out:
# Payment Method Counts:
# PayPal           677
# Credit Card      671
# Cash             670
# Debit Card       636
# Venmo            634
# Bank Transfer    612
# Name: Payment Method, dtype: int64

# %%
shopping_data.value_counts('Payment Method')
# Out:
# Payment Method
# PayPal           677
# Credit Card      671
# Cash             670
# Debit Card       636
# Venmo            634
# Bank Transfer    612
# dtype: int64

# %%
shopping_data.groupby('Payment Method').count()
# Out:
#                 Customer ID  Age  Gender  Item Purchased  Category  \
# Payment Method
# Bank Transfer           612  612     612             612       612
# Cash                    670  670     670             670       670
# Credit Card             671  671     671             671       671
# Debit Card              636  636     636             636       636
# PayPal                  677  677     677             677       677
# Venmo                   634  634     634             634       634
#
#                 Purchase Amount (USD)  Location  Size  Color  Season  \
# Payment Method
# Bank Transfer                     612       612   612    612     612
# Cash                              670       670   670    670     670
# Credit Card                       671       671   671    671     671
# Debit Card                        636       636   636    636     636
# PayPal                            677       677   677    677     677
# ...

# %%
shopping_data['Payment Method'].unique()
# Out:
# array(['Venmo', 'Cash', 'Credit Card', 'PayPal', 'Bank Transfer',
#        'Debit Card'], dtype=object)

# %% [markdown]
# ####Average Purchase Amount (USD) of customer age above 40 yr?

# %%
average_purchase_age_above_40 = shopping_data[shopping_data['Age'] > 40]['Purchase Amount (USD)'].mean()

print("Average Purchase Amount (USD) for Customers > 40 years old:", average_purchase_age_above_40)
# Out:
# Average Purchase Amount (USD) for Customers > 40 years old: 59.57277628032345

# %%
shopping_data[shopping_data['Age']>40].mean()
# Out:
# <ipython-input-36-a42cdc3ecb6a>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   shopping_data[shopping_data['Age']>40].mean()
# Customer ID              1954.827942
# Age                        55.384097
# Purchase Amount (USD)      59.572776
# Review Rating               3.731851
# Previous Purchases         25.689128
# dtype: float64

# %% [markdown]
# #Visualization

# %%
import pandas as pd
shopping = pd.read_csv('/content/drive/MyDrive/bsc_dpdm_23/customer_shopping_data.csv')

# %%
from matplotlib import pyplot as plt

# %%
shopping
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %% [markdown]
# ##Histogram

# %% [markdown]
# #### Branch distribution

# %%
histoutput = plt.hist(shopping['shopping_mall'])
tickhist = plt.xticks(rotation='vertical')

# %%
histoutput[0]
# Out:
# array([19823.,  4947., 15011., 10161.,  9781., 19943.,  4811.,  4991.,
#         4914.,  5075.])

# %%
tickhist[-1]
# Out:
# [Text(0, 0, 'Kanyon'),
#  Text(1, 0, 'Forum Istanbul'),
#  Text(2, 0, 'Metrocity'),
#  Text(3, 0, 'Metropol AVM'),
#  Text(4, 0, 'Istinye Park'),
#  Text(5, 0, 'Mall of Istanbul'),
#  Text(6, 0, 'Emaar Square Mall'),
#  Text(7, 0, 'Cevahir AVM'),
#  Text(8, 0, 'Viaport Outlet'),
#  Text(9, 0, 'Zorlu Center')]

# %%
tickhist[-1][0].get_text()
# Out:
# 'Kanyon'

# %% [markdown]
# #Scatter

# %% [markdown]
# #### Is there a trend in age vs price?

# %%
plt.scatter(shopping['age'],shopping['price'],alpha=0.5)  ##อายุ 18-70 ซื้อของราคาถูกเหมือนกัน ซื้อของแพงเหมือนกัน แต่ซื้อไม่เยอะเท่าของราคาถูก

# %% [markdown]
# #### Is there a trend in price VS quantity?

# %%
plt.scatter(shopping['price'],shopping['quantity'],alpha=0.5)

# %% [markdown]
# #### Are there outliers in the price?

# %% [markdown]
# #Box Plot

# %%
import matplotlib.pyplot as plt
bpreturn = plt.boxplot(shopping['price'])

# Access the outliers
outliers = bpreturn['fliers'][0]

# %%
bpreturn['fliers']

# %%
bpreturn['fliers'][0].get_ydata()
# Out:
# array([3000.85, 3000.85, 5250.  , ..., 3150.  , 3150.  , 4200.  ])

# %%
len(bpreturn['fliers'][0].get_ydata())
# Out:
# 5024

# %% [markdown]
# #Pie Chart

# %% [markdown]
# #### ration of male and female customer

# %%
import matplotlib.pyplot as plt

# %%
males = len(shopping[shopping[gender]=='Male'])
females =len( shopping[shopping[gender]=='Females'])
plt.pie([males,females],labels =['Male','Females']);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-109-c4ee1ba10925> in <cell line: 1>()
# ----> 1 males = len(shopping[shopping[gender]=='Male'])
#       2 females =len( shopping[shopping[gender]=='Females'])
#       3 plt.pie([males,females],labels =['Male','Females']);
#
# NameError: name 'gender' is not defined

# %% [markdown]
# #Bar Chart

# %% [markdown]
# ####Stacked

# %% [markdown]
# เปรียบเทียบชนิดสินค้า

# %% [markdown]
# #Distance - Similarity

# %%
import pandas as pd
from scipy.spatial import distance_matrix

# %%
import numpy as np

# %%
data_point = np.array

# %%
LA.norm(data_)

# %% [markdown]
# # z-score
